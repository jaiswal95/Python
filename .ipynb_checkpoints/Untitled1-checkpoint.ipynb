# %%
type(len("""5"""))
# Out:
# int

# %%
type(len('5'))
# Out:
# int

# %%
len("5")
# Out:
# 1

# %%
type(len("5"))
# Out:
# int

# %%
type(len("Hello"))
# Out:
# int

# %%
def string_length(mystring):
    return len(mystring)
print(string_length("Hello"))
# Out:
# 5

# %%
def converter(original_unit,coefficient):
    return original_unit ** coefficient
print(converter(3,3))
# Out:
# 27

# %%
from sklearn.datasets import make_blobs
X,Y=make_blobs(n_features=3,n_samples=1000,centers=7)

# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
plt.scatter(X[:,0],X[:,1],c=Y)

# %%
from sklearn.kmeanss import kmeans
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-65-0a158552af38> in <module>
# ----> 1 from sklearn.kmeanss import kmeans
#
# ModuleNotFoundError: No module named 'sklearn.kmeanss'
